# %% [markdown]
# # Problem Set 1 (96 points)

# %% [markdown]
# ## Important information
# 1. We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.
#
# 2. Please submit the single Jupyter Notebook file, where only Python and Markdown/$\LaTeX$ are used. Any hand-written solutions inserted by photos or in any other way **are prohibitive and will not be graded**. If you will have any questions about using Markdown, ask them!

# %% [markdown]
# # Problem 1 (Theoretical tasks)  (36 pts)
#
# _1._
# - (1 pts) What are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{1} \leq \|x\|_{\infty} \leq C_2 \| x\|_{1}$ for any vector $x$
# - (5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.
# - (5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.
#
# _2._
# - (5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. _Hint:_ SVD will help you.
# - (5 pts) Show that for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.
# - (5 pts) Prove that if $A \in \mathbb{R}^{n \times n}$ - diagonalizable matrix, then $\det(\exp(A)) = \exp(\mathrm{trace}(A))$.
#
# _Hint:_ $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S$, moreover $\exp(D) = \mathrm{diag}(\exp(d_1), \exp(d_2), ..., \exp(d_n))$ where $D = \mathrm{diag}(d_1, d_2, ..., d_n)$ - diagonal matrix with diagonal values $d_1, d_2, ..., d_n$
#
#
# - (5 pts) Prove that $\| A B \|_2 \le \| A \|_2 \| B \|_F$.
#
# _3._
#
# - (2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
# Find a pseudoinverse of $UU^*$
# - (3 pts) Compute  pseudoinverse of the matrix analytically
#
# $$
# A = \begin{bmatrix}
# 2\\
# 3\\
# \vdots\\
# \sqrt{5n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$

# %% [markdown]
# **Answers**
# ### 1.1
# $||x||_{\infty} = \max_i|x_i| $,       $||x||_1 = \Sigma_i|x_i|$
#
# but $\Sigma_i|x_i| \le n*\max_i|x_i| \implies \frac{1}{n}\Sigma_i|x_i| \le \max_i|x_i|$ ***also*** $\max_i|x_i| \le \Sigma_i|x_i|$
#
# $\implies \frac{1}{n}\Sigma_i|x_i| \le \max_i|x_i| \le \Sigma_i|x_i|$
#
# $C_1 = \frac{1}{n}, C_2 = 1 $
#
# ### 1.2
# $\operatorname{trace} UA = \operatorname{trace} u_{ij}a_{jk} = u_{ij}a_{ji} = a_{ji}u_{ij} = \operatorname{trace} AU \Rightarrow \operatorname{trace} UA = \operatorname{trace} AU$
# $\|A\|_F = \sqrt{\mathrm{trace} \big[A^*A\big]} = \sqrt{\mathrm{trace} \big[A^*IA\big]} = \sqrt{\mathrm{trace} \big[A^*(U^*U)A\big]} = \sqrt{\mathrm{trace} \big[(A^*U^*)(UA)\big]} = \|UA\|_F.$
# $\|AU\|_F = \sqrt{\mathrm{trace} \big[(AU)^*(AU)\big)} = \sqrt{\mathrm{trace} \big[U^*A^*AU\big]} = \sqrt{\mathrm{trace} \big[A^*A\big]} = \|A\|_F.$
# $\implies$ $\| A \|_F = \| U A \|_F = \| A U \|_F $
#
# ### 1.3
# $\|UA\|_2 =  \sqrt{\lambda_{max} \big[(UA)^*(UA)\big]} =  \sqrt{\lambda_{max} \big[(A^*U^*UA)\big]} =  \sqrt{\lambda_{max} \big[A^*A\big]} = \|A\|_2$
# $\|AU\|_2 =  \sqrt{\lambda_{max} \big[(AU)^*(AU)\big]} $[AB and BA have the same eigenvalues](https://www.quora.com/How-would-one-show-that-the-eigenvalues-of-AB-and-BA-are-always-the-same-where-A-B-are-square-matrices-of-order-n)$ =  \sqrt{\lambda_{max} \big[(AU)(AU)^*\big]} =  \sqrt{\lambda_{max} \big[AUU^*A^*)\big]} =  \sqrt{\lambda_{max} \big[AA^*\big]} = \|A\|_2$
# $\implies$$\|UA\|_2 = \|AU\|_2 = \|A\|_2$
#
# ### 2.1
# $||A||_{2}^2 = \lambda_{max}(A^{*}A), ||A||_{F}^2 = \operatorname{tr}(A^{*}A)$
#
# $A = U \Sigma V^{*}$, where  $\Sigma$ is diagonal matrix with non-zero elements $\sigma_1 >= \sigma_2 >= ... >= \sigma_k$ on diagonal, $U$ and $V$ are unitary matrixes. $Rank(A)$ is amount of non-zero sigular values of $A$
#
# $$||A||_{2}^2 = \lambda_{max} (\Sigma^{*}\Sigma) = \sigma_{1}^2(A), \ ||A||_{F}^2 = \operatorname{tr}(\Sigma^{*}\Sigma) = \sum_{i}(\sigma_{i}^2)$$
#
# Let's take $rank(A) = r$. We get for non-zero sigma's $\sum_{i=1}^{r}(\sigma_{i}^2) \le \sigma_{1}^2 \times r,$ as $\sigma_1$ is the largest singular value. It proves: $||A||_{F} \le \sqrt{rank(A)} \times ||A||_{2}$
#
# ### 2.2
# There exists $A \in \mathbb{R}^{m \times n}$ matrix of rank $k$ with $k$ equal nonzero singular values. Lets Say $A$ = $\mathbb{I}^{m \times n} $ where only $k$ diagonal elements are 1 and rest are 0 $\implies $ rank = $k$
#
# $\|A\|_{F} = \sqrt{\sum\limits_{i=1}^k 1^2} = \sqrt{k}.$
# Therefore, $ \|A\|_{F} = \sqrt{k} \|A\|_{2} \Rightarrow \| A \|_F = \sqrt{rank(A)} \| A \|_2,$
# $\|A\|_{2} = \sqrt{\lambda_{max}(A^{*}A)} = 1$
#
# ### 2.3
# $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S$ take det both sides
#
# $\det(\exp(S^{-1}AS)) = \det(S^{-1}\exp(A)S) = \det(S^{-1})\det(S)\det(\exp(A)) = \det(\exp(A))$
#
# Since A is diagonalizable via SVD form of pre and post streatching using Unitary martices
#
# $\det(\exp(A)) = \prod_{i=1}^n\exp(d_i) = \exp\Sigma_{i=1}^nd_i = \exp(\mathrm{trace}(A))  $ where $d_i$ represents the diagonal elements of the diagonalized form representation of A
#
# ### 2.4
#
# From the [Cauchy Schwarz inequality](https://en.wikipedia.org/wiki/Cauchy%E2%80%93Schwarz_inequality) $\| A B \|_2 \le \| A \|_2 \| B \|_2$
#
# let $σ_{1},σ_{2}.....σ_{n}$ be the singular values of $B$
#
# $$||B||_{2}^2 = \lambda_{max} (\Sigma^{*}\Sigma) = \sigma_{1}^2(B), \ ||B||_{F}^2 = \operatorname{tr}(\Sigma^{*}\Sigma) = \sum_{i}(\sigma_{i}^2)$$
#
# since $\sum_{i}(\sigma_{i}^2) \ge \sigma_{1}^2 \implies ||B||_F \ge ||B||_2$ substituting back in the Cauchy Schwartz inequality we get
#
# $\| A B \|_2 \le \| A \|_2 \| B \|_F$
#
# ### 3.1
#
# $U \in \mathbb{C}^{n \times k}, k < n$
#
# $U^*U = I_k$
#
# From [Moore Penrose](https://en.wikipedia.org/wiki/Moore%E2%80%93Penrose_inverse) conditions of pseudo inverse if $A^+$ is the pseudoinverse of A then it satisfies: $AA^+A = A$
# Using this property for $U^*U$ and supposing $U^+$ being the pseudoinverse
#
# $\implies UU^*U^+UU^* = UU^*$
# $\implies U^*U^+UU^* = U^* \implies U^*U^+U = I_k$
#
# Since the dimentions of multiplications are $k*n*(dim(U^+)*n*k$ and $U^*, U $ is unitary $\implies U^+ = I_n$
#
# ### 3.2
#
# For a real matrix $A = USV^T$ and $A^+ = VS^+U^T $ where $S^+$ is the reciprocal of non zero diagonal elements of $S$
#
# $$
# A = \begin{bmatrix}
# -1 & 1 & -1 & \dots & (-1)^n \\
# -\sqrt{3} & \sqrt{3} & -\sqrt{3} & \dots & (-1)^n\sqrt{3} \\
# \vdots & \vdots & \vdots & \dots & \vdots\\
# -\sqrt{2n-1} & \sqrt{2n-1} & -\sqrt{2n-1} & \dots & (-1)^n\sqrt{2n-1} \\
# \end{bmatrix}
# $$
#
#
# $$rank(A) = 1$$<br/>
# $A = U S V^T$, where $U \in \mathbb{R}^{n \times r}, S \in \mathbb{R}^{r \times r}$ and $V \in \mathbb{R}^{n \times r}$<br/>
# Let's compute singular values of $A$ by computing eigenvalues of $AA^T$, which results in only 1 value.<br/>
# $
# AA^T = \begin{bmatrix}
# n & \dots & \dots & \dots \\
# \vdots & 3n & \dots & \dots \\
# \vdots & \vdots & \dots & \vdots\\
# \dots & \dots & \dots & n(2n-1) \\
# \end{bmatrix}
# $<br/>
# and using the fact that $tr(AA^T) = \sum_{i=1}^n \lambda_i$<br/>
# $tr(AA^T) = n + 3n + 5n + \dots + n(2n-1)$<br/>
# $= n(1 + 3 + \dots + (2n-1))$<br/>
# $= n\Big( (1+2+\dots+2n) - 2(1+2+\dots+n)\Big)$<br/>
# Applying progression rules, we get $n^3$<br/>
# So, $\lambda_1 = n^3$ and $\sigma_1 = \sqrt{n^3}$<br/>
# Hence, $S = \begin{bmatrix} \sqrt{n^3}\\ \end{bmatrix}, S^{-1} = \begin{bmatrix} \frac{1}{\sqrt{n^3}}\\ \end{bmatrix}$<br/>
#  $V=\begin{bmatrix}
# \frac{1}{\sqrt{n}}\\
# \vdots\\
# \frac{1}{\sqrt{n}}\\
# \end{bmatrix}$ <br/>
# Hence, $V^T=\begin{bmatrix}
# \frac{1}{\sqrt{n}}&\dots&\frac{1}{\sqrt{n}}
# \end{bmatrix}$<br/>
# <br/>
#  $U=AVS^{-1}$ to compute $U$, we get that $VS^{-1} = \begin{bmatrix}
# \frac{1}{n^2}\\
# \vdots\\
# \frac{1}{n^2}\\
# \end{bmatrix}$ <br/>
# Therefore, $AVS^{-1} =
# \begin{bmatrix}
# (-1)^n\frac{1}{n^2}\\
# (-1)^n\frac{\sqrt{3}}{n^2}\\
# \vdots\\
# (-1)^n\frac{\sqrt{(2n-1)}}{n^2}\\
# \end{bmatrix}$ <br/>
# <br/>
# The result is as follows:
# $A = USV^T$<br/>
# $= \begin{bmatrix}
# (-1)^n\frac{1}{n^2}\\
# (-1)^n\frac{\sqrt{3}}{n^2}\\
# \vdots\\
# (-1)^n\frac{\sqrt{(2n-1)}}{n^2}\\
# \end{bmatrix} \begin{bmatrix} \frac{1}{\sqrt{n^3}}\\ \end{bmatrix} \begin{bmatrix}
# \frac{1}{\sqrt{n}}&\dots&\frac{1}{\sqrt{n}}
# \end{bmatrix}$
#
# $A^+ = VSU^T\implies$
# $A^+=\begin{bmatrix}
# \frac{1}{\sqrt{n}}\\\vdots\\\frac{1}{\sqrt{n}}
# \end{bmatrix}\begin{bmatrix} \sqrt{n^3}\\ \end{bmatrix} \begin{bmatrix}
# (-1)^n\frac{1}{n^2}
# (-1)^n\frac{\sqrt{3}}{n^2}
# \dots
# (-1)^n\frac{\sqrt{(2n-1)}}{n^2}
# \end{bmatrix}$

# %% [markdown]
# # Problem 2 (Matrix calculus) (15 pts)
#
# _1._ (11 pts) Consider the following function
#
# $$ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \times n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$ is given diagonal matrix.
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$
# - (7 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion
#
# _2._ (4 pts) Derive analytical expression for the gradient and hessian of the function $f$:
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix. Why the gradient of this function is important in NLA you will know in the lectures later.

# %% [markdown]
# ### 1.1
#
#
# $$ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2, $$
# $$F(U, V) = \frac{1}{2}\mathrm{trace}[(X-UDV)^T(X-UDV)]$$
# $$\implies F(U, V) = \frac{1}{2}\mathrm{trace}[X^TX - X^TUDV - V^TDU^TX + V^TDU^TUDV]$$
# $$\implies F(U, V)=\frac{1}{2}\mathrm{trace}(X^TX)-\frac{1}{2}\mathrm{trace}(X^TUDV)-\frac{1}{2}\mathrm{trace}(V^TDU^TX)+\frac{1}{2}\mathrm{trace}(V^TDU^TUDV)$$
#
# using $\mathrm{trace}(A) = \mathrm{trace}(A^T)$ and property derived in seminar for $\nabla_U\mathrm{trace}(AUB) = A^TB^T$ we get:
#
# $\nabla_UF(U, V) = -\frac{1}{2}XV^TD-\frac{1}{2}XV^TD+\frac{1}{2}UDVV^TD+\frac{1}{2}UDVV^TD = (-X+UDV)V^TD$
#
# ### 1.2
#
# Similarly
#
# $\nabla_VF(U, V) = -\frac{1}{2}DU^TX-\frac{1}{2}DU^TX+\frac{1}{2}DU^TUDV+\frac{1}{2}DU^TUDV = DU^T(-X+UDV)$
#
# ### 1.3
# $$\frac{\partial F}{\partial V}, \frac{\partial F}{\partial U}$$ both take $$~O(k^4n^2)$$

# %%
# Your solution is here
import jax
import jax.numpy as jnp

@jax.jit
def f(X, U, D, V):
  res = jnp.linalg.norm(X - U @ D @ V, ord='fro') 
  return 1/2 * res ** 2

@jax.jit
def agrad_u(X, U, D, V):
  return (-X + U @ D @ V) @ V.T @ D

@jax.jit
def agrad_v(X, U, D, V):
  return D @ U.T @ (-X + U @ D @ V)

# %%
grad_f_u = jax.grad(f, argnums=1, has_aux=False)
grad_f_v = jax.grad(f, argnums=3, has_aux=False)

jit_grad_u = jax.jit(grad_f_u)
jit_grad_v = jax.jit(grad_f_v)

# %%
N, K = 1000, 700

X = jax.random.normal(jax.random.PRNGKey(0), (N, N))
U = jax.random.normal(jax.random.PRNGKey(0), (N, K))
D = jnp.diag(jax.random.normal(jax.random.PRNGKey(0), (K,)))
V = jax.random.normal(jax.random.PRNGKey(0), (K, N))
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
import timeit

starttime = timeit.default_timer()
(-X + U @ D @ V) @ V.T @ D, D @ U.T @ (-X + U @ D @ V)
print('Analytical time:', round((timeit.default_timer() - starttime), 3))

starttime = timeit.default_timer()
grad_f_u(X, U, D, V).block_until_ready(), grad_f_v(X, U, D, V).block_until_ready()
print('\nOut-of-box time:', round((timeit.default_timer() - starttime), 3))

starttime = timeit.default_timer()
jit_grad_u(X, U, D, V).block_until_ready(), jit_grad_v(X, U, D, V).block_until_ready()
print('\nJitted out-of-box time:', round((timeit.default_timer() - starttime), 3))
# Out:
# Analytical gradient function took 0.349
#
# Out-of-box gradient function: took 0.445
#
# Jitted out-of-box gradient function: took 0.441

# %%
import matplotlib.pyplot as plt
import numpy as np
import timeit

np.random.seed(10)

# %%
ns = jnp.logspace(1, 4, num=7, endpoint=True).astype(int)
ks = jnp.logspace(1, 4, num=7, endpoint=True).astype(int)
grad_u_times, grad_v_times = [], []

for i in range(len(ks)):
  n_dims = []
  k = ks[i]
  for j in range(i + 1, len(ns)):
    n = ns[j]
    n_dims.append(n)
    
    X = np.random.rand(n, n)
    U = np.random.rand(k, k)
    D = np.random.rand(k,)
    V = np.random.rand(k, n)

    start_time = timeit.default_timer()
    grad_f_u(X, U, D, V)
    grad_u_times.append(timeit.default_timer() - start_time)

    start_time = timeit.default_timer()
    grad_f_v(X, U, D, V)
    grad_v_times.append(timeit.default_timer() - start_time)

  if i + 1 < len(ns):
    fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(7, 3))
    fig.suptitle('Using k={}'.format(k), fontsize=16)

    ax1.plot(n_dims, grad_u_times, 'r-,')
    ax1.set_xscale('log')
    ax1.set_xlabel('$n$')
    ax1.set_ylabel('grad_u time (s)')
    
    ax2.plot(n_dims, grad_v_times, 'g-,')
    ax2.set_xscale('log')
    ax2.set_xlabel('$n$')
    ax2.set_ylabel('grad_v time (s)')

    plt.show()

    grad_u_times.clear()
    grad_v_times.clear()

# %% [markdown]
# Conclusion: As we notice that the analytic solution is faster
#
#  n dominates k till the order of roughly $\approx 10^3$ and after this point f starts to dominate

# %% [markdown]
# ### 2
# $$R(x) = \frac{A_{ij}x_jx_i}{x_kx_k} \Rightarrow \frac{\partial R}{\partial x_n} = \frac{A_{in}x_i + A_{nj}x_j}{x_kx_k} - 2\frac{A_{ij}x_jx_i}{(x_kx_k)^2}x_n = \frac{x^TA + Ax}{(x, x)} - 2 \frac{(Ax, x)}{(x, x)^2}x$$
# Using: A is a symmetric matrix, then:
# $$\frac{\partial R}{\partial x} = \frac{2Ax}{(x, x)} - 2 \frac{(Ax, x)}{(x, x)^2}x$$
#
# similarly differential wrt x again:
#
# $$d^2R(x) = 2(-2\|x\|^{-4}_2(x, dx_2)(Ax, dx_1) + \|x\|^{-2}_2(dx_2, Adx_1) - 4\|x\|^{-6}_2(x, dx_2)(Ax, x)(x, dx_1) \\ + 2\|x\|^{-4}_2(Ax, dx_2)(x, dx_1) + \|x\|^{-4}_2(Ax, x)(dx_2, dx_1))$$
#
#
#
# $$\nabla^2 R(x) = 2\|x\|^{-2}_2(-2\|x\|^{-2}_2xx^TA + A - 4\|x\|^{-4}_2xx^TAxx^T + 2\|x\|^{-2}_2Axx^T + \|x\|^{-2}_2x^TAx)$$

# %% [markdown]
# # Problem 3. Compression of the fully-connected layers in neural network with simple architecture (30 pts)
#
# In this problem we consider the neural network that performs classification of the dataset of images.
# Any neural network can be considered as composition of simple linear and non-linear functions.
# For example, a neural network with 3 layers can be represented as
#
# $$f_3(f_2(f_1(x, w_1), w_2), w_3),$$
#
# where $x$ is input data (in our case it will be images) and $w_i, \; i =1,\dots,3$ are parameters that are going to be trained.
#
# We will study the compression potential of neural network with simple architecture: alternating some numbers of linear and non-linear functions.
#
# The main task in this problem is to study how the compression of fully-connected layers affects the test accuracy.
# Any fully-connected layer is represented as linear function $AX + B$, where $X$ is input matrix and $A, B$ are trainable matrices. Matrices $A$ in every layer are going to be compressed.
# The main result that you should get is the plot of dependence of test accuracy on the total number of parameters in the neural network.

# %% [markdown]
# #### Zero step: install PyTorch
#
# - Follow the steps in [official instructions](https://pytorch.org/get-started/locally/)

# %% [markdown]
# #### First step: download CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./

# %% [markdown]
# #### Check what images are we going to classify

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
# truck   dog  frog truck  deer  deer  deer  deer

# %% [markdown]
# ### Second step: neural network architecture
#
# For simplicity and demonstration purposes of the neural network compression idea consider the architecture consisting of the only fully-connected layers and non-linear ReLU functions between them.
# To demonstrate compression effect, consider the dimension of the inner layers equals to 1000.
#
# Below you see implementation of such neural network in PyTorch.
# More details about neural networks you will study in the *Deep learning* course in one of the upcoming term

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, middle_features, activation=nn.ReLU()):
        super().__init__()
        self.layer1 = nn.Linear(in_features, middle_features)
        self.layer2 = nn.Linear(middle_features, in_features)
        self.activation = activation
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.activation(out)
        out = self.layer2(out)
        out = out + x
        out = self.activation(out)
        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.res1 = ResidualBlock(1000,1000)
        self.res2 = ResidualBlock(1000,1000)
        self.fc2 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# #### Implement functions for training and testing after every sweep over all dataset entries

# %%
def train(model, train_loader, optimizer, epoch):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.train()
    model.to(device)
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    device = "cuda" if torch.cuda.is_available() else "cpu"
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# ### Set parameters for training and print intermediate loss values

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ### Third step: run training with the [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document) optimization method
#
# If your laptop is not very fast, you will wait some time till training is finished.

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.291734
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.724565
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.661428
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.591630
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.593009
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.437206
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.456125
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.558183
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.553898
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.429203
#
# Test set: Average loss: 1.4984, Accuracy: 4728/10000 (47%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.472084
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.449464
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.454575
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.326099
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.657388
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.354283
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.276708
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.378150
# Train Epoch: 2 [40000/50000 (80%)]	Loss: 1.607867
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 1.247923
#
# Test set: Average loss: 1.4099, Accuracy: 5091/10000 (51%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.302149
# Train Epoch: 3 [5000/50000 (10%)]	Loss: 1.182090
# Train Epoch: 3 [10000/50000 (20%)]	Loss: 1.292707
# Train Epoch: 3 [15000/50000 (30%)]	Loss: 1.186263
# Train Epoch: 3 [20000/50000 (40%)]	Loss: 1.294535
# Train Epoch: 3 [25000/50000 (50%)]	Loss: 1.138918
# Train Epoch: 3 [30000/50000 (60%)]	Loss: 1.410074
# Train Epoch: 3 [35000/50000 (70%)]	Loss: 1.287841
# Train Epoch: 3 [40000/50000 (80%)]	Loss: 1.123454
# Train Epoch: 3 [45000/50000 (90%)]	Loss: 1.410487
#
# Test set: Average loss: 1.3816, Accuracy: 5157/10000 (52%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.227491
# Train Epoch: 4 [5000/50000 (10%)]	Loss: 1.119862
# Train Epoch: 4 [10000/50000 (20%)]	Loss: 1.064608
# Train Epoch: 4 [15000/50000 (30%)]	Loss: 1.103150
# Train Epoch: 4 [20000/50000 (40%)]	Loss: 0.989594
# Train Epoch: 4 [25000/50000 (50%)]	Loss: 1.164625
# Train Epoch: 4 [30000/50000 (60%)]	Loss: 0.991375
# Train Epoch: 4 [35000/50000 (70%)]	Loss: 1.270787
# Train Epoch: 4 [40000/50000 (80%)]	Loss: 1.202774
# Train Epoch: 4 [45000/50000 (90%)]	Loss: 1.247693
#
# Test set: Average loss: 1.3796, Accuracy: 5160/10000 (52%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.142252
# Train Epoch: 5 [5000/50000 (10%)]	Loss: 0.799599
# Train Epoch: 5 [10000/50000 (20%)]	Loss: 0.910916
# Train Epoch: 5 [15000/50000 (30%)]	Loss: 1.040504
# Train Epoch: 5 [20000/50000 (40%)]	Loss: 0.912016
# Train Epoch: 5 [25000/50000 (50%)]	Loss: 0.937878
# Train Epoch: 5 [30000/50000 (60%)]	Loss: 1.098117
# Train Epoch: 5 [35000/50000 (70%)]	Loss: 0.960368
# Train Epoch: 5 [40000/50000 (80%)]	Loss: 1.118185
# Train Epoch: 5 [45000/50000 (90%)]	Loss: 1.231660
#
# Test set: Average loss: 1.3897, Accuracy: 5372/10000 (54%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.897791
# Train Epoch: 6 [5000/50000 (10%)]	Loss: 1.021584
# Train Epoch: 6 [10000/50000 (20%)]	Loss: 0.956087
# Train Epoch: 6 [15000/50000 (30%)]	Loss: 0.839808
# Train Epoch: 6 [20000/50000 (40%)]	Loss: 0.985870
# Train Epoch: 6 [25000/50000 (50%)]	Loss: 1.078230
# Train Epoch: 6 [30000/50000 (60%)]	Loss: 1.095929
# Train Epoch: 6 [35000/50000 (70%)]	Loss: 0.975343
# Train Epoch: 6 [40000/50000 (80%)]	Loss: 1.049344
# Train Epoch: 6 [45000/50000 (90%)]	Loss: 0.995833
#
# Test set: Average loss: 1.4743, Accuracy: 5232/10000 (52%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.671219
# Train Epoch: 7 [5000/50000 (10%)]	Loss: 0.842252
# Train Epoch: 7 [10000/50000 (20%)]	Loss: 0.899864
# Train Epoch: 7 [15000/50000 (30%)]	Loss: 0.898073
# Train Epoch: 7 [20000/50000 (40%)]	Loss: 0.709556
# Train Epoch: 7 [25000/50000 (50%)]	Loss: 0.809523
# Train Epoch: 7 [30000/50000 (60%)]	Loss: 0.981801
# Train Epoch: 7 [35000/50000 (70%)]	Loss: 0.919257
# Train Epoch: 7 [40000/50000 (80%)]	Loss: 0.974429
# Train Epoch: 7 [45000/50000 (90%)]	Loss: 0.711124
#
# Test set: Average loss: 1.4818, Accuracy: 5440/10000 (54%)

# %% [markdown]
# Now we have somehow trained neural network and we are ready to perform compression of the weigths in the fully-connected layers.

# %% [markdown]
# - (3 pts) Compute SVD of the matrix $1000 \times 1000$, which corresponds to a weight matrix $A$ in each layer of residual blocks. To find more information about accessing this matrix please refer to [PyTorch manual](https://pytorch.org/docs/stable/index.html).
# Plot decaying of the singular values like it was shown in the lecture. What conclusion can you make?
# - (17 pts) Create a new model, which is an analogue to the class ```Net```, but with some significant distinctions.
# It takes as input parameters the instance of the class ```Net``` and compression rank $r > 0$.
# After that, this model has to compress all matrices $A$ in fully-connected layers with SVD using first $r$ singular vectors and singular values.
# Pay attention to efficient storing of compress representation of the layers.
# Also ```forward``` method of your new residual block has to be implemented in a way to use compressed representation of the fully-connected layers (inside it) in the most efficient way. In all other aspects it has to reproduce ```forward``` method in the original non-compressed model (number of layers, activations, loss function etc).
# - (5 pts) Plot dependence of test accuracy on the number of parameters in the compressed model. This number of parameters obviously depends on the compression rank $r$.
# Also plot dependence of time to compute inference on the compression rank $r$.
# Explain obtained results.
# To measure time, use [%timeit](https://docs.python.org/3.6/library/timeit.html) with necessary parameters (examples of using this command see in lectures)
#
# - (5 pts) After such transformations, your model depends on the factors obtained from SVD. Therefore, these factors are also can be trained with the same gradient method during some number of epochs. This procedure is called **fine-tuning**. We ask you make this fine-tuning of your compressed model during from 1 to 5 epochs and compare the result test accuracy with the test accuracy that you get after compression. Explain the observed results.
#
#     **Hint 1**. Please, check that during fine-tuning, factors are updated. If they are not updated according to some reason, please check that their parameter ```requires_grad``` is setted to ```True```.
#
#     **Hint 2**. You can use class ```torch.nn.Parameter``` to convert factors to parameters of the network

# %%
plt.figure(figsize=(5,5))

W1 = model.res1.layer1.weight.data 
s1 = np.linalg.svd(W1, compute_uv=False)
plt.plot(s1/s1[0])
W2 = model.res1.layer2.weight.data 
s2 = np.linalg.svd(W2, compute_uv=False)
plt.plot(s2/s2[0])
W3 = model.res2.layer1.weight.data 
s3 = np.linalg.svd(W3, compute_uv=False)
plt.plot(s3/s3[0])
W4 = model.res2.layer2.weight.data 
s4 = np.linalg.svd(W4, compute_uv=False)
plt.plot(s4/s4[0])
plt.title('Plot1', fontsize=18)
plt.xlabel("SVD index", fontsize=18)
plt.ylabel("Normalised magnitude", fontsize=18)
plt.legend(['res1_layer1', 'res1_layer2', 'res2_layer1', 'res2_layer2'], loc='upper right', prop={'size': 10})
plt.show()

# %% [markdown]
# ###Conclusion:
# It's clear that the singular values, related to the weights of $1000 \times 1000$ FC_1,FC_2 layers(1,2) is getting decayed in a rapid manner. Thus, we can make use of SVD in order to apply some compressions.

# %%
layers =  [(W1), (W2), (W3), (W4)]

small_svs = 1000
THRESHOLD = 1e-3

for layer in layers:
  D = np.linalg.svd(layer, compute_uv=False)

  small_svs = min(small_svs, len(np.where(abs(D) < THRESHOLD)))

# %%
class MyResidualBlock(nn.Module):
    def __init__(self, res_block, r):
        super().__init__()
        self.layer1_UD, self.layer1_V = self.get_compressed_layer(res_block.layer1, r)
        self.layer2_UD, self.layer2_V = self.get_compressed_layer(res_block.layer2, r)
        self.activation = res_block.activation
        
    def get_compressed_layer(self, layer, r):
        new_layer_V = nn.Linear(r, 1000, bias=False)
        new_layer_UD = nn.Linear(1000, r, bias=False)

        U, D, V = torch.svd(layer.weight)

        new_layer_V.weight = nn.Parameter((V.T[:r]))
        new_layer_UD.weight = nn.Parameter(((U[:, :r]) @ torch.diag(D[:r])))
        new_layer_UD.bias = nn.Parameter(layer.bias) 

        return new_layer_UD, new_layer_V
    
    def forward(self, x):
        out = self.layer1_UD(self.layer1_V(x))
        out = self.activation(out)
        out = self.layer2_UD(self.layer2_V(out))
        out = out + x
        out = self.activation(out)
        return out

class MyNet(nn.Module):
    def __init__(self, model, r):
        super(MyNet, self).__init__()
        self.fc1 = model.fc1
        self.res1 = MyResidualBlock(model.res1, r)
        self.res2 = MyResidualBlock(model.res2, r)
        self.fc2 = model.fc2
        self.ReLU = model.ReLU

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
my_model = MyNet(model=model, r=(1000-small_svs))
optimizer = optim.Adam(my_model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(my_model,  train_loader, optimizer, epoch)
    test(my_model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 0.595789
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 0.971244
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.020309
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.192103
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 0.944151
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 0.865741
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 0.904563
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 0.818490
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 0.866889
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 0.949399
#
# Test set: Average loss: 1.5241, Accuracy: 5279/10000 (53%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.776647
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 0.675820
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 0.812744
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.091063
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 0.805457
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 0.949973
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 0.637736
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.035332
# Train Epoch: 2 [40000/50000 (80%)]	Loss: 0.812214
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 0.988157
#
# Test set: Average loss: 1.4984, Accuracy: 5226/10000 (52%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.831395
# Train Epoch: 3 [5000/50000 (10%)]	Loss: 0.493106
# Train Epoch: 3 [10000/50000 (20%)]	Loss: 0.753403
# Train Epoch: 3 [15000/50000 (30%)]	Loss: 0.740537
# Train Epoch: 3 [20000/50000 (40%)]	Loss: 0.844292
# Train Epoch: 3 [25000/50000 (50%)]	Loss: 0.920672
# Train Epoch: 3 [30000/50000 (60%)]	Loss: 0.922172
# Train Epoch: 3 [35000/50000 (70%)]	Loss: 0.813912
# Train Epoch: 3 [40000/50000 (80%)]	Loss: 0.621056
# Train Epoch: 3 [45000/50000 (90%)]	Loss: 0.710575
#
# Test set: Average loss: 1.5086, Accuracy: 5287/10000 (53%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.761727
# Train Epoch: 4 [5000/50000 (10%)]	Loss: 0.861525
# Train Epoch: 4 [10000/50000 (20%)]	Loss: 0.694539
# Train Epoch: 4 [15000/50000 (30%)]	Loss: 0.610472
# Train Epoch: 4 [20000/50000 (40%)]	Loss: 0.583367
# Train Epoch: 4 [25000/50000 (50%)]	Loss: 0.817564
# Train Epoch: 4 [30000/50000 (60%)]	Loss: 0.720146
# Train Epoch: 4 [35000/50000 (70%)]	Loss: 1.018638
# Train Epoch: 4 [40000/50000 (80%)]	Loss: 0.749901
# Train Epoch: 4 [45000/50000 (90%)]	Loss: 0.910153
#
# Test set: Average loss: 1.5522, Accuracy: 5266/10000 (53%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.639740
# Train Epoch: 5 [5000/50000 (10%)]	Loss: 0.746879
# Train Epoch: 5 [10000/50000 (20%)]	Loss: 0.598363
# Train Epoch: 5 [15000/50000 (30%)]	Loss: 0.909998
# Train Epoch: 5 [20000/50000 (40%)]	Loss: 0.686353
# Train Epoch: 5 [25000/50000 (50%)]	Loss: 0.731982

# %%
n_params_list = []
acc_list = []
times_list = []

ranks_list = np.logspace(1, 4, num=9, base=10.).astype(int)
for r in ranks_list:
  mdl = MyNet(model, r)
  
  parameters = sum(p.numel() for p in mdl.parameters())
  n_params_list.append(parameters)
  
  starttime = timeit.default_timer()
  accuracy = test(mdl, test_loader)
  
  times_list.append(timeit.default_timer() - starttime)
  acc_list.append(accuracy)

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(nrows=2, ncols=2, figsize=(14, 11))

ax1.plot(ranks_list, acc_list)
ax1.set_xlabel('Compression Rank', fontsize=15)
ax1.set_ylabel('Accuracy', fontsize=15)
ax1.set_title('Compression Rank vs. Accuracy', fontsize=20)

ax2.plot(n_params_list, acc_list)
ax2.set_xlabel('# of Parameters', fontsize=15)
ax2.set_ylabel('Accuracy', fontsize=15)
ax2.set_title('# of Parameters vs. Accuracy', fontsize=20)

ax3.plot(ranks_list, n_params_list)
ax3.set_xlabel('# of Parameters', fontsize=15)
ax3.set_ylabel('Compression Rank', fontsize=15)
ax3.set_title('# of Parameters vs. Compression Rank', fontsize=20)

ax4.plot(ranks_list, times_list)
ax4.set_xlabel('Compression Rank', fontsize=15)
ax4.set_ylabel('Testing Time', fontsize=15)
ax4.set_title('Compression Rank vs. Testing Time', fontsize=20)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Problem 4. «Reducio!» (15 pts)

# %% [markdown]
# Hermione Granger is well versed in all magical disciplines. In particular, she is a great expert in Numerical Linear Algebra and JAX.
#
# She has invited Harry Potter to play the game.
#
# Hermione chooses a number $r \in [1, 95]$ and two matrices $W_1 \in \mathbb{R}^{r \times 100}$ and $W_2 \in \mathbb{R}^{100 \times r}$.
# Harry can tell her any 100-dimensional vector $x$, and Hermione gives Harry the result of
#
# $$ ||\sin(W_2 \cos(W_1 x))||^2_2,$$
#
# where trigonometric functions are applied element-wise. The result is the squared norm of a 100-dimensional vector.
#
# Not to lose, Harry should guess what number $r$ Hermione has chosen.
# Harry knows the python language, but he is an absolute layman in algebra. Please, help him to get at least 95% correct answers!
#
# <i> Hint 1: SVD might help you, but use it wisely! </i>
#
# <i> Hint 2: Suppose that a special magic allows you to compute gradients through automatic differentiation in JAX. You can also estimate gradients via finite differences, if you want it.</i>
#
# <i> Hint 3: You can estimate the matrix rank using simple heuristics.
#
# You should write code into the `harry_answers` function. Good luck!

# %%
import jax.numpy as jnp
import jax
import numpy as np
import random

class Game:
    def __init__(self, key):
        # key is a jax.random.PRNGKey
        self.key = key
        return
    def hermione_chooses_r_and_W(self):
        self.r = random.randint(1, 95)
        self.key, subkey = jax.random.split(self.key)
        self.W1 = jax.random.uniform(subkey, (self.r, 100), maxval=100., minval=0., dtype=jnp.float32)
        self.key, subkey = jax.random.split(self.key)
        self.W2 = jax.random.uniform(subkey, (100, self.r), maxval=100., minval=0., dtype=jnp.float32)
    def hermione_computes_function(self, x):
        return jnp.sum(jnp.square(jnp.sin(self.W2 @ jnp.cos(self.W1 @ x))))
    def harry_answers(self):
       n=100
       samples = jax.random.normal(self.key, (100,n))
       gradients = jax.grad(self.hermione_computes_function, argnums=0)

       gradients_l = jnp.apply_along_axis(gradients, 1, samples)/n**0.5
       s = jnp.linalg.svd(gradients_l, compute_uv = False)
       s = np.round(s)
       s = s[s >= 1]

       return len(s)

       
    
    def play(self, n_rounds, verbose=True):
        # n_rounds: a number of rounds of the game
        # verbose: print or not the result of each round
        n_right_answers = 0
        for _ in range(n_rounds):
            self.hermione_chooses_r_and_W()
            r = self.harry_answers()
            if abs(r - self.r) == 0:
                if verbose:
                    print("Good job! The true answer is {}, Harry's answer is {}!".format(self.r, r))
                n_right_answers += 1
            else:
                if verbose:
                    print("Harry's answers is {}, but the true answer is {} :(".format(r, self.r))
        if float(n_right_answers) / n_rounds > 0.95:
            print('Well done: {}/{} right answers!'.format(n_right_answers, n_rounds))
        else:
            print('Only {}/{} right answers :( Work a little more and you will succeed!'.format(
                n_right_answers, n_rounds))

# %%
key = jax.random.PRNGKey(713)
game = Game(key)
game.play(n_rounds=100, verbose=False)
# Out:
# Well done: 100/100 right answers!
